# %%
import numpy as np

# %%
import matplotlib as mpl

# %%
import pandas as pd

# %%
print(5+3)
# Out:
# 8

# %%
x = 5
y = 7
if x>3:
    print(y+7)
# Out:
# 14

# %%
df = pd.read_csv("data\CustomerChurn.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\KIIT0001\AppData\Local\Temp\ipykernel_8324\159634786.py:1: SyntaxWarning: invalid escape sequence '\C'
#   df = pd.read_csv("data\CustomerChurn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
import seaborn as sns
import matplotlib.pyplot as plt



df['Churn'].value_counts()

sns.countplot(data = df, x = 'Churn')
plt.title('Churn')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(data = df, x = 'gender', hue = 'Churn')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(data = df, x = 'PaymentMethod', hue = 'Churn')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
payment_churn = df.groupby('PaymentMethod')['Churn'].value_counts(normalize=True).unstack()
print(payment_churn)
# Out:
# Churn                            No       Yes
# PaymentMethod
# Bank transfer (automatic)  0.832902  0.167098
# Credit card (automatic)    0.847569  0.152431
# Electronic check           0.547146  0.452854
# Mailed check               0.808933  0.191067

# %%
sns.countplot(data = df, x = 'Contract', hue = 'Churn')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#plt.figure(figsize=(10,8))
#sns.heatmap(correle, annot = True, cmap = 'coolwarm')
#plt.show

df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df['Churn_numeric'] = df['Churn'].map({'No': 0, 'Yes': 1})

# Optionally convert other categorical variables if needed
# Select only numeric columns
numeric_df = df.select_dtypes(include=['int64', 'float64'])

# Add Churn_numeric if it's not already there
if 'Churn_numeric' not in numeric_df.columns:
    numeric_df['Churn_numeric'] = df['Churn_numeric']

correle = numeric_df.corr()

plt.figure(figsize=(10,8))
sns.heatmap(correle, annot=True, cmap='coolwarm', fmt=".2f")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(5,3))

sns.boxplot(x = 'Churn', y = 'tenure', data = df)
plt.title('Churn vs tenure')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(5,3))

sns.boxplot(x = 'Churn', y = 'MonthlyCharges', data = df)
plt.title('Monthelycharges vs tenure')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.kdeplot(data=df[df['Churn'] == 'Yes']['MonthlyCharges'], label='Churned', fill=True, color='red')
sns.kdeplot(data=df[df['Churn'] == 'No']['MonthlyCharges'], label='Stayed', fill=True, color='green')
plt.title('KDE of Monthly Charges by Churn')
plt.legend()
plt.show()
